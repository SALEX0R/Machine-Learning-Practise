# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import folium
from folium.plugins import HeatMap
import sys

# %%
data=pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding='latin1')
data
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       197000000001   1970       7     2  ...        0         0       0      NaN
# 1       197000000002   1970       0     0  ...        1         1       1      NaN
# 2       197001000001   1970       1     0  ...       -9         1       1      NaN
# 3       197001000002   1970       1     0  ...       -9         1       1      NaN
# 4       197001000003   1970       1     0  ...       -9         1       1      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# ...

# %%
data.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
fig = plt.figure(figsize=(80, 85))
m = Basemap(projection='cyl', resolution=None,
            llcrnrlat=-90, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180,lat_0=0, lon_0=0 )
m.shadedrelief()
m.scatter(data['longitude'],data['latitude'], latlon=True, 
          cmap='Reds', alpha=0.5,color='red')

# %%
year=data.groupby('iyear')['eventid'].count()
year
# Out:
# iyear
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: eventid, dtype: int64

# %%
fig = plt.figure(figsize=(80, 85))
m = Basemap(projection='cyl', resolution=None,
            llcrnrlat=-90, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180,lat_0=0, lon_0=0 )
m.shadedrelief()
m.pcolormesh(data=data['longitude','latitude'],cmap="Reds", shading='gouraud')
